# %%
#PUBG api key
api_key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiIwNTE3ZmU2MC1lMTcyLTAxMzctYWMyZC0wZjEwZDJiNjFmOTQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTcyOTAwMzU0LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImJsYWNraXR0eTI0LW5hIn0.GCcQkphe-lhgzDamBXFESkrFo2XZZSp5h6TRW3EW0Ag"

# %%
from chicken_dinner.pubgapi import PUBG

# %%
pubg = PUBG(api_key, "pc-na")

# %%
samples = pubg.samples()

# %%
sample_matches = samples.match_ids

# %%
match = pubg.match(sample_matches[12])

# %%
#This is the match that works!
sample_matches[12]
# Out:
# '93f8e820-115c-4c76-9a84-5f3631d59379'

# %%
match_telemetry = match.get_telemetry()

# %%
from chicken_dinner.pubgapi import PUBG
from chicken_dinner.visual.playback import create_playback_animation


create_playback_animation(match_telemetry, "match.html")
# Out:
# True

# %%
match2 = pubg.match(sample_matches[20])

# %%
#This is the match that works!
sample_matches[20]
# Out:
# 'b64bebf1-a9f6-46a4-8357-c719c0ed5ab1'

# %%
match_telemetry2 = match2.get_telemetry()

# %%
from chicken_dinner.pubgapi import PUBG
from chicken_dinner.visual.playback import create_playback_animation

create_playback_animation(match_telemetry2, "match2.html")
# Out:
# True
